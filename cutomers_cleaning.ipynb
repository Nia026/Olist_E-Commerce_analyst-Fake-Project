# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dc = pd.read_csv('raw_dataset/olist_customers_dataset.csv') 
dc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %%
dc.columns.is_unique #Check data duplikat di setiap kolom (output: True)
# Out:
# True

# %%
#Check jumlah missing value di setiap kolom  
print('customer_id: ', dc['customer_id'].isna().sum())
print('customer_unique_id: ', dc['customer_unique_id'].isna().sum())
print('customer_zip_code_prefix: ', dc['customer_zip_code_prefix'].isna().sum())
print('customer_city: ', dc['customer_city'].isna().sum()) 
print('customer_state: ', dc['customer_state'].isna().sum())
# Out:
# customer_id:  0
# customer_unique_id:  0
# customer_zip_code_prefix:  0
# customer_city:  0
# customer_state:  0

# %%
dc['customer_city'].value_counts(dropna = False) #Check kategori penulisan kolom customer_city
# Out:
# customer_city
# sao paulo              15540
# rio de janeiro          6882
# belo horizonte          2773
# brasilia                2131
# curitiba                1521
#                        ...
# siriji                     1
# natividade da serra        1
# monte bonito               1
# sao rafael                 1
# eugenio de castro          1
# Name: count, Length: 4119, dtype: int64

# %%
dc['customer_state'].value_counts(dropna = False) #Check kategori penulisan kolom customer_state
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
dc.tail()
# Out:
#                             customer_id                customer_unique_id  \
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix    customer_city customer_state
# 99436                      3937        sao paulo             SP
# 99437                      6764  taboao da serra             SP
# 99438                     60115        fortaleza             CE
# 99439                     92120           canoas             RS
# 99440                      6703            cotia             SP
