# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dc = pd.read_csv('raw_dataset/olist_orders_dataset.csv') 
dc.info() 
dc.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# ...

# %%
dc.columns.is_unique #Check data duplikat di setiap kolom (output: True)
# Out:
# True

# %%
#Check jumlah missing value di setiap kolom  
print('order_id: ', dc['order_id'].isna().sum())
print('customer_id: ', dc['customer_id'].isna().sum())
print('order_status: ', dc['order_status'].isna().sum())
print('order_purchase_timestamp: ', dc['order_purchase_timestamp'].isna().sum()) 
print('order_approved_at: ', dc['order_approved_at'].isna().sum()) 
print('order_delivered_carrier_date: ', dc['order_delivered_carrier_date'].isna().sum()) 
print('order_delivered_customer_date: ', dc['order_delivered_customer_date'].isna().sum()) 
print('order_estimated_delivery_date: ', dc['order_estimated_delivery_date'].isna().sum())
# Out:
# order_id:  0
# customer_id:  0
# order_status:  0
# order_purchase_timestamp:  0
# order_approved_at:  160
# order_delivered_carrier_date:  1783
# order_delivered_customer_date:  2965
# order_estimated_delivery_date:  0

# %%
dc['order_approved_at'].value_counts(dropna = False) #Check kategori penulisan kolom order_approve_at
# Out:
# order_approved_at
# NaT                    160
# 2018-02-27 04:31:10      9
# 2017-11-07 07:30:38      7
# 2018-02-06 05:31:52      7
# 2018-07-05 16:33:01      7
#                       ...
# 2017-03-09 09:54:05      1
# 2018-02-06 13:10:37      1
# 2017-08-27 15:04:16      1
# 2018-01-08 21:36:21      1
# 2018-03-09 11:20:28      1
# Name: count, Length: 90734, dtype: int64

# %%
dc['order_approved_at']=pd.to_datetime(dc['order_approved_at'], format='%Y-%m-%d %H:%M:%S')

# %%
dc['order_purchase_timestamp']=pd.to_datetime(dc['order_purchase_timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
dc['order_delivered_carrier_date']=pd.to_datetime(dc['order_delivered_carrier_date'], format='%Y-%m-%d %H:%M:%S')

# %%
dc['order_delivered_customer_date']=pd.to_datetime(dc['order_delivered_customer_date'], format='%Y-%m-%d %H:%M:%S')

# %%
dc['order_estimated_delivery_date']=pd.to_datetime(dc['order_estimated_delivery_date'], format='%Y-%m-%d %H:%M:%S')

# %%
dc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  datetime64[us]
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[us]
#  6   order_delivered_customer_date  96476 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[us]
# dtypes: datetime64[us](5), str(3)
# memory usage: 6.1 MB

# %%
dc.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
dc['order_status'].value_counts(dropna=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
dc.to_csv('clean_dataset/orders_cleaned.csv', index=False, encoding='utf-8')
